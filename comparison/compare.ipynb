# %%
import matplotlib.pyplot as plt
# %matplotlib inline

X1 = [2100, 5100, 10100, 15100, 20100, 25100, 30100, 35100, 40100, 45100, 50100, 55100, 60100, 65100, 70100, 75100, 80100, 85100, 90100, 95100, 99100]
Y1 = [1.0073, 2.4293, 4.9419, 7.5129, 9.8839, 12.358, 15.001, 17.406, 19.883, 22.272, 24.673, 27.038, 30.346, 32.858, 35.266, 37.774, 39.955, 42.352, 44.811, 47.679, 49.744]

X2 = [1000, 5000, 10000, 15000, 20000, 25000, 32768]
Y2 = [3000, 16000, 31000, 47000, 62000, 78000, 106000]

plt.plot(X1, Y1, 'ro-', label="ours")

plt.plot(X2, Y2, 'bo-', label="tails file")

plt.xlabel('Number of credentials')
plt.ylabel('Time(ms)')
plt.yscale('log')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

X = [1000, 5000, 9000, 13000, 17000, 21000, 25000, 29000, 33000, 37000, 41000, 45000, 49000, 53000, 57000, 61000, 65000, 69000, 73000, 77000, 81000, 85000, 89000, 93000, 97000]
Y = [0.22263, 1.7439, 4.1027, 10.033, 14.287, 22.899, 32.247, 42.065, 48.53, 35.283, 45.449, 48.016, 53.113, 58.119, 62.913, 69.672, 73.222, 79.399, 90.632, 96.012, 90.583, 97.242, 112.66, 104.81, 129.44]

plt.plot(X, Y, 'ro-')

plt.xlabel('Number of credentials')
plt.ylabel('Time(ms)')

plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

X = [1000, 5000, 9000, 13000, 17000, 21000, 25000, 29000, 33000, 37000, 41000, 45000, 49000, 53000, 57000, 61000, 65000, 69000, 73000, 77000, 81000, 85000, 89000, 93000, 97000]
Y = [0.22507, 1.7209, 3.9416, 9.9997, 14.934, 22.972, 32.327, 43.033, 52.566, 37.793, 42.923, 49.424, 54.166, 60.604, 62.335, 64.707, 72.941, 79.335, 85.178, 88.127, 90.804, 96.653, 102.78, 109.46, 113.51]

plt.plot(X, Y, 'ro-')

plt.xlabel('Number of credentials')
plt.ylabel('Time(ms)')

plt.show()
